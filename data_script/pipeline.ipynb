# %%
# %load_ext autoreload
# %autoreload 2
from generate_by_depth import generate_by_depth
import numpy as np
from pathlib import Path
from generate_random import generate_random

max_value = 10
sample_num = 10
depth = 3
max_arity= 3
max_c = 3
max_r = 3


eq_domain = [np.zeros((1))] + [
    np.random.randint(1, max_value + 1, size=(sample_num, dim))
    for dim in range(1, max_arity + 1)
]
eq_domain[1] = np.arange(10).reshape(10, 1)

temp_dir = Path("/home/takeru/AlphaSymbol/temp/")


generate_by_depth(
    depth=depth,
    max_arity=max_arity,
    max_c=max_c,
    max_r=max_r,
    eq_domain=eq_domain,
    output_file=temp_dir / "generate_by_depth.csv"
)

generate_random(
    max_count=5,
    max_generate_count=10,
    max_p_arity=max_arity,
    max_c_args = max_c,
    max_r_args = max_r,
    eq_domain=eq_domain,
    output_path=temp_dir / "generate_random.csv",
    init_csv=temp_dir / "generate_by_depth.csv"
)
# Out:
# DEBUG:root:Z() added
# DEBUG:root:S() added
# DEBUG:root:C(S(), Z()) added
# DEBUG:root:C(S(), S()) added
# DEBUG:root:C(S(), P(2, 1)) added
# DEBUG:root:C(S(), P(2, 2)) added
# DEBUG:root:C(S(), P(3, 1)) added
# DEBUG:root:C(S(), P(3, 2)) added
# DEBUG:root:C(S(), P(3, 3)) added
# DEBUG:root:R(S(), P(2, 1), Z()) added
# DEBUG:root:R(P(1, 1), P(2, 1), Z()) added
# DEBUG:root:R(S(), P(3, 2), S()) added
# DEBUG:root:R(P(1, 1), P(3, 1), S()) added
# DEBUG:root:C(S(), C(S(), Z())) added
# DEBUG:root:C(C(S(), S()), C(S(), Z())) added
# DEBUG:root:C(S(), C(S(), S())) added
# DEBUG:root:C(S(), R(S(), P(2, 1), Z())) added
# DEBUG:root:C(C(S(), S()), C(S(), S())) added
# DEBUG:root:C(C(S(), S()), R(S(), P(2, 1), Z())) added
# DEBUG:root:C(R(S(), P(2, 1), Z()), R(P(1, 1), P(2, 1), Z())) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), R(P(1, 1), P(2, 1), Z())) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), P(1, 1), Z()) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), P(1, 1), C(S(), Z())) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), R(P(1, 1), P(2, 1), Z()), Z()) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), R(P(1, 1), P(2, 1), Z()), C(S(), Z())) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), P(1, 1), C(S(), S())) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), R(P(1, 1), P(2, 1), Z()), S()) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), R(P(1, 1), P(2, 1), Z()), P(1, 1)) added
# DEBUG:root:C(R(P(1, 1), P(3, 1), S()), R(P(1, 1), P(2, 1), Z()), C(S(), S())) added
# DEBUG:root:C(S(), C(S(), P(2, 1))) added
# DEBUG:root:C(S(), R(S(), P(3, 2), S())) added
# DEBUG:root:C(C(S(), S()), C(S(), P(2, 1))) added
# DEBUG:root:C(C(S(), S()), R(S(), P(3, 2), S())) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), P(2, 2)) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), R(P(1, 1), P(3, 1), S())) added
# DEBUG:root:C(S(), C(S(), P(3, 1))) added
# DEBUG:root:C(S(), C(S(), P(3, 2))) added
# DEBUG:root:C(S(), C(S(), P(3, 3))) added
# DEBUG:root:C(C(S(), S()), C(S(), P(3, 1))) added
# DEBUG:root:C(C(S(), S()), C(S(), P(3, 2))) added
# DEBUG:root:C(C(S(), S()), C(S(), P(3, 3))) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), P(3, 1)) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), P(3, 2)) added
# DEBUG:root:C(R(P(1, 1), P(2, 1), Z()), P(3, 3)) added
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# DEBUG:root:R(S(), P(2, 1), C(S(), Z())) added
# DEBUG:root:R(S(), R(S(), P(3, 2), S()), Z()) added
# DEBUG:root:R(S(), R(S(), P(3, 2), S()), C(S(), Z())) added
# DEBUG:root:R(S(), R(P(1, 1), P(3, 1), S()), Z()) added
# DEBUG:root:R(S(), R(P(1, 1), P(3, 1), S()), C(S(), Z())) added
# DEBUG:root:R(P(1, 1), R(S(), P(3, 2), S()), Z()) added
# DEBUG:root:R(P(1, 1), R(P(1, 1), P(3, 1), S()), Z()) added
# DEBUG:root:R(C(S(), S()), P(2, 1), C(S(), Z())) added
# DEBUG:root:R(C(S(), S()), R(S(), P(3, 2), S()), C(S(), Z())) added
# DEBUG:root:R(C(S(), S()), R(P(1, 1), P(3, 1), S()), Z()) added
# DEBUG:root:R(C(S(), S()), R(P(1, 1), P(3, 1), S()), C(S(), Z())) added
# DEBUG:root:R(R(S(), P(2, 1), Z()), R(S(), P(3, 2), S()), Z()) added
# DEBUG:root:R(R(S(), P(2, 1), Z()), R(P(1, 1), P(3, 1), S()), Z()) added
# DEBUG:root:R(R(S(), P(2, 1), Z()), R(P(1, 1), P(3, 1), S()), C(S(), Z())) added
# DEBUG:root:R(R(P(1, 1), P(2, 1), Z()), R(S(), P(3, 2), S()), Z()) added
# DEBUG:root:R(R(P(1, 1), P(2, 1), Z()), R(P(1, 1), P(3, 1), S()), Z()) added
# DEBUG:root:R(R(P(1, 1), P(2, 1), Z()), R(P(1, 1), P(3, 1), S()), C(S(), Z())) added
# DEBUG:root:R(S(), C(S(), P(3, 2)), S()) added
# DEBUG:root:R(S(), C(S(), P(3, 2)), P(1, 1)) added
# DEBUG:root:R(S(), C(S(), P(3, 2)), C(S(), S())) added
# DEBUG:root:R(S(), C(S(), P(3, 2)), R(P(1, 1), P(2, 1), Z())) added
# DEBUG:root:R(P(1, 1), C(S(), P(3, 2)), R(P(1, 1), P(2, 1), Z())) added
# DEBUG:root:R(C(S(), S()), C(S(), P(3, 2)), C(S(), S())) added
# DEBUG:root:R(R(P(1, 1), P(2, 1), Z()), P(3, 2), R(P(1, 1), P(2, 1), Z())) added
# DEBUG:root:R(R(P(1, 1), P(2, 1), Z()), C(S(), P(3, 2)), R(P(1, 1), P(2, 1), Z())) added
# INFO:root:Output file is updated. There are 75 exprs
# INFO:root:Output file is updated. There are 20 exprs
# INFO:root:Output file is updated. There are 40 exprs
# INFO:root:Output file is updated. There are 60 exprs
# INFO:root:Output file is updated. There are 80 exprs
# DEBUG:root:Iter 0: 10 is added
# INFO:root:Output file is updated. There are 100 exprs
# DEBUG:root:Iter 1: 10 is added
# DEBUG:root:Iter 2: 10 is added
# INFO:root:Output file is updated. There are 120 exprs
# DEBUG:root:Iter 3: 10 is added
# DEBUG:root:Iter 4: 10 is added
